# %%
import pandas as pd
import os

# %%
# cwd = os.getcwd()
path = "c:\\Users\\Martijn\\Downloads\\"

path
# Out:
# 'c:\\Users\\Martijn\\Downloads\\'

# %%
# df = pd.read_excel(path + "ExpertReviewsClean43LIWC.xlsx")
# print(df.head())
# df = df.drop(columns=['Analytic', 'Clout', 'Authentic', 'Tone', 'WPS', 'Sixltr', 'Dic',
#                       'function', 'pronoun', 'ppron', 'i', 'we', 'you', 'shehe', 'they', 
#                       'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#                       'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'affect',
#                       'posemo', 'negemo', 'anx', 'anger', 'sad', 'social', 'family', 'friend',
#                       'female', 'male', 'cogproc', 'insight', 'cause', 'discrep', 'tentat',
#                       'certain', 'differ', 'percept', 'see', 'hear', 'feel', 'bio', 'body',
#                       'health', 'sexual', 'ingest', 'drives', 'affiliation', 'achieve',
#                       'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture',
#                       'relativ', 'motion', 'space', 'time', 'work', 'leisure', 'home', 'money',
#                       'relig', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu',
#                       'filler', 'AllPunc', 'Period', 'Comma', 'Colon', 'SemiC', 'QMark', 'Exclam',
#                       'Dash', 'Quote', 'Apostro', 'Parenth', 'OtherP'])
# df.to_csv(path + "ExpertReviews.csv")
# Out:
#                                         url  idvscore            reviewer  \
# 0  https://www.metacritic.com/movie/bronson     100.0    "Andrew O'Hehir"
# 1  https://www.metacritic.com/movie/bronson      90.0        'A.O. Scott'
# 2  https://www.metacritic.com/movie/bronson      90.0                None
# 3  https://www.metacritic.com/movie/bronson      83.0       'Noel Murray'
# 4  https://www.metacritic.com/movie/bronson      80.0   'Joshua Rothkopf'
#
#    dateP                                                Rev  WC  Analytic  \
# 0   None   'Bronson owes a little or a lot to Kubrick s ...  25     73.88
# 1   None   'Bronson invites you to admire its protagonis...  30     13.07
# 2   None   'Whether it s Peterson/Bronson s more theatri...  40     72.69
# 3   None   'There are two Bronsons on display here: the ...  39     65.46
# 4   None   'Refn has somehow found his way to an authent...  24     88.46
#
# ...

# %%
df = pd.read_csv(path + "ExpertReviews.csv", index_col=0)
df
# Out:
#                                                    url  idvscore  \
# 0             https://www.metacritic.com/movie/bronson     100.0
# 1             https://www.metacritic.com/movie/bronson      90.0
# 2             https://www.metacritic.com/movie/bronson      90.0
# 3             https://www.metacritic.com/movie/bronson      83.0
# 4             https://www.metacritic.com/movie/bronson      80.0
# ...                                                ...       ...
# 238968  https://www.metacritic.com/movie/spirited-away      80.0
# 238969  https://www.metacritic.com/movie/spirited-away      75.0
# 238970  https://www.metacritic.com/movie/spirited-away      75.0
# 238971  https://www.metacritic.com/movie/spirited-away      75.0
# 238972  https://www.metacritic.com/movie/spirited-away      75.0
#
#                   reviewer  dateP  \
# 0         "Andrew O'Hehir"   None
# 1             'A.O. Scott'   None
# 2                     None   None
# 3            'Noel Murray'   None
# ...

# %%
df["movie_id"] = df["url"].str.split("/", expand=True)[:][4]
df
# Out:
#                                                    url  idvscore  \
# 0             https://www.metacritic.com/movie/bronson     100.0
# 1             https://www.metacritic.com/movie/bronson      90.0
# 2             https://www.metacritic.com/movie/bronson      90.0
# 3             https://www.metacritic.com/movie/bronson      83.0
# 4             https://www.metacritic.com/movie/bronson      80.0
# ...                                                ...       ...
# 238968  https://www.metacritic.com/movie/spirited-away      80.0
# 238969  https://www.metacritic.com/movie/spirited-away      75.0
# 238970  https://www.metacritic.com/movie/spirited-away      75.0
# 238971  https://www.metacritic.com/movie/spirited-away      75.0
# 238972  https://www.metacritic.com/movie/spirited-away      75.0
#
#                   reviewer  dateP  \
# 0         "Andrew O'Hehir"   None
# 1             'A.O. Scott'   None
# 2                     None   None
# 3            'Noel Murray'   None
# ...

# %%
df.head(50)
# Out:
#                                                  url  idvscore  \
# 0           https://www.metacritic.com/movie/bronson     100.0
# 1           https://www.metacritic.com/movie/bronson      90.0
# 2           https://www.metacritic.com/movie/bronson      90.0
# 3           https://www.metacritic.com/movie/bronson      83.0
# 4           https://www.metacritic.com/movie/bronson      80.0
# 5           https://www.metacritic.com/movie/bronson      80.0
# 6           https://www.metacritic.com/movie/bronson      80.0
# 7           https://www.metacritic.com/movie/bronson      78.0
# 8           https://www.metacritic.com/movie/bronson      75.0
# 9           https://www.metacritic.com/movie/bronson      75.0
# 10          https://www.metacritic.com/movie/bronson      75.0
# 11          https://www.metacritic.com/movie/bronson      75.0
# 12          https://www.metacritic.com/movie/bronson      75.0
# 13          https://www.metacritic.com/movie/bronson      75.0
# ...

# %%
new.describe()
# Out:
# count            238973
# unique            11364
# top       dune-part-one
# freq                 67
# Name: 4, dtype: object

# %%
type(new)
# Out:
# pandas.core.series.Series

# %%
new[238970][-1]
# Out:
# 'spirited-away'
